# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 779

# %%
import requests

from config import weather_api_key

import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f3a2560397bcadb7f1af3b16b263bffe

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
#city_data = []

# Print the beginning of the logging.
#print("Beginning Data Retrieval    ")
#print("----------------------------")

# Create counters.
#record_count = 1
#set_count = 1

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
       

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
   
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_des = city_weather["weather"][0]["description"]
          
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_des})    
     


    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | eureka
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | pavino
# Processing Record 4 of Set 1 | san juan
# Processing Record 5 of Set 1 | pangnirtung
# Processing Record 6 of Set 1 | flinders
# Processing Record 7 of Set 1 | coquimbo
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | jacareacanga
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | guozhen
# Processing Record 17 of Set 1 | luau
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | malakal
# Processing Record 20 of Set 1 | chuy
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | san felipe
# Processing Record 23 of Set 1 | maracas
# Processing Record 24 of Set 1 | kendari
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | hengshui
# Processing Record 29 of Set 1 | fallbrook
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | college
# Processing Record 32 of Set 1 | mount darwin
# Processing Record 33 of Set 1 | miandrivazo
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | grand forks
# Processing Record 38 of Set 1 | lope de vega
# Processing Record 39 of Set 1 | rocha
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | port-gentil
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | garissa
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | hobyo
# Processing Record 48 of Set 1 | eyl
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | scarborough
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | xucheng
# Processing Record 5 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | acapulco
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | voznesenye
# Processing Record 14 of Set 2 | tilichiki
# Processing Record 15 of Set 2 | sidi ali
# Processing Record 16 of Set 2 | port hardy
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | santa ana
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | sinjar
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | beian
# Processing Record 24 of Set 2 | leningradskiy
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | pasni
# Processing Record 28 of Set 2 | lavrentiya
# Processing Record 29 of Set 2 | san cristobal
# Processing Record 30 of Set 2 | mount isa
# Processing Record 31 of Set 2 | poya
# Processing Record 32 of Set 2 | darlawn
# Processing Record 33 of Set 2 | kulim
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | belfast
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | salinopolis
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | nurobod
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | yulara
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | axim
# Processing Record 44 of Set 2 | mackay
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | witu
# Processing Record 47 of Set 2 | anadyr
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | mar del plata
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | ushuaia
# Processing Record 3 of Set 3 | along
# Processing Record 4 of Set 3 | te anau
# Processing Record 5 of Set 3 | kupang
# Processing Record 6 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 3 | touros
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | nuuk
# Processing Record 10 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | berlevag
# Processing Record 13 of Set 3 | port macquarie
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 3 | kaeo
# Processing Record 18 of Set 3 | la ronge
# Processing Record 19 of Set 3 | morondava
# Processing Record 20 of Set 3 | tezu
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | bengkulu
# Processing Record 23 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | aliwal north
# Processing Record 26 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 27 of Set 3 | metro
# Processing Record 28 of Set 3 | palmer
# Processing Record 29 of Set 3 | harper
# Processing Record 30 of Set 3 | dingle
# Processing Record 31 of Set 3 | marsaxlokk
# Processing Record 32 of Set 3 | launceston
# Processing Record 33 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 3 | bambanglipuro
# Processing Record 35 of Set 3 | nelson bay
# Processing Record 36 of Set 3 | faya
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | grand gaube
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | ixtapa
# Processing Record 41 of Set 3 | nchelenge
# Processing Record 42 of Set 3 | altamira
# Processing Record 43 of Set 3 | labuan
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | yelizovo
# Processing Record 46 of Set 3 | karratha
# Processing Record 47 of Set 3 | clyde river
# Processing Record 48 of Set 3 | itapirapua
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | esperance
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | arraial do cabo
# Processing Record 3 of Set 4 | valparaiso
# Processing Record 4 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | ouango
# Processing Record 7 of Set 4 | havre-saint-pierre
# Processing Record 8 of Set 4 | muskegon
# Processing Record 9 of Set 4 | beira
# Processing Record 10 of Set 4 | srednekolymsk
# Processing Record 11 of Set 4 | sencur
# Processing Record 12 of Set 4 | banjar
# Processing Record 13 of Set 4 | lahat
# Processing Record 14 of Set 4 | saint george
# Processing Record 15 of Set 4 | kloulklubed
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 18 of Set 4 | lakselv
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | poum
# Processing Record 21 of Set 4 | puteyets
# Processing Record 22 of Set 4 | omboue
# Processing Record 23 of Set 4 | kikwit
# Processing Record 24 of Set 4 | kommunisticheskiy
# Processing Record 25 of Set 4 | atasu
# Processing Record 26 of Set 4 | saint-louis
# Processing Record 27 of Set 4 | san policarpo
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | iqaluit
# Processing Record 30 of Set 4 | tambopata
# Processing Record 31 of Set 4 | praya
# Processing Record 32 of Set 4 | atar
# Processing Record 33 of Set 4 | houma
# Processing Record 34 of Set 4 | makakilo city
# Processing Record 35 of Set 4 | ambon
# Processing Record 36 of Set 4 | kondinskoye
# Processing Record 37 of Set 4 | jaumave
# Processing Record 38 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | alta floresta
# Processing Record 40 of Set 4 | khilok
# Processing Record 41 of Set 4 | tamandare
# Processing Record 42 of Set 4 | constitucion
# Processing Record 43 of Set 4 | quesnel
# Processing Record 44 of Set 4 | key largo
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | resistencia
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | chalmette
# Processing Record 49 of Set 4 | puri
# Processing Record 50 of Set 4 | sitka
# Processing Record 1 of Set 5 | clarence town
# Processing Record 2 of Set 5 | nyurba
# Processing Record 3 of Set 5 | ridgetown
# Processing Record 4 of Set 5 | vila velha
# Processing Record 5 of Set 5 | haines junction
# Processing Record 6 of Set 5 | ponta delgada
# Processing Record 7 of Set 5 | banda aceh
# Processing Record 8 of Set 5 | nemuro
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | chokurdakh
# Processing Record 11 of Set 5 | odweyne
# Processing Record 12 of Set 5 | fairbanks
# Processing Record 13 of Set 5 | yenagoa
# Processing Record 14 of Set 5 | sakaiminato
# Processing Record 15 of Set 5 | port blair
# Processing Record 16 of Set 5 | uzhur
# Processing Record 17 of Set 5 | shemonaikha
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | sabinas hidalgo
# Processing Record 20 of Set 5 | san patricio
# Processing Record 21 of Set 5 | savelugu
# Processing Record 22 of Set 5 | tiksi
# Processing Record 23 of Set 5 | cockburn town
# Processing Record 24 of Set 5 | port-cartier
# Processing Record 25 of Set 5 | vega de alatorre
# Processing Record 26 of Set 5 | hasaki
# Processing Record 27 of Set 5 | uribia
# Processing Record 28 of Set 5 | necochea
# Processing Record 29 of Set 5 | okha
# Processing Record 30 of Set 5 | gat
# Processing Record 31 of Set 5 | goundi
# Processing Record 32 of Set 5 | nerchinskiy zavod
# Processing Record 33 of Set 5 | roswell
# Processing Record 34 of Set 5 | nabire
# Processing Record 35 of Set 5 | pyapon
# Processing Record 36 of Set 5 | marsh harbour
# Processing Record 37 of Set 5 | riyadh
# Processing Record 38 of Set 5 | new norfolk
# Processing Record 39 of Set 5 | klyuchi
# Processing Record 40 of Set 5 | kavieng
# Processing Record 41 of Set 5 | cap malheureux
# Processing Record 42 of Set 5 | marzuq
# Processing Record 43 of Set 5 | markova
# Processing Record 44 of Set 5 | vastervik
# City not found. Skipping...
# Processing Record 45 of Set 5 | nenjiang
# Processing Record 46 of Set 5 | hami
# Processing Record 47 of Set 5 | celestun
# Processing Record 48 of Set 5 | port shepstone
# Processing Record 49 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 5 | fasa
# Processing Record 1 of Set 6 | khatanga
# Processing Record 2 of Set 6 | puerto del rosario
# Processing Record 3 of Set 6 | geraldton
# Processing Record 4 of Set 6 | taunggyi
# Processing Record 5 of Set 6 | ormara
# Processing Record 6 of Set 6 | rawson
# Processing Record 7 of Set 6 | beclean
# Processing Record 8 of Set 6 | saint-pierre
# Processing Record 9 of Set 6 | muros
# Processing Record 10 of Set 6 | ulladulla
# Processing Record 11 of Set 6 | zarubino
# Processing Record 12 of Set 6 | archidona
# Processing Record 13 of Set 6 | mongo
# Processing Record 14 of Set 6 | meulaboh
# Processing Record 15 of Set 6 | annapolis
# Processing Record 16 of Set 6 | kilmez
# City not found. Skipping...
# Processing Record 17 of Set 6 | hirara
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 6 | vanimo
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | victoria point
# Processing Record 23 of Set 6 | wagar
# Processing Record 24 of Set 6 | namatanai
# Processing Record 25 of Set 6 | komsomolskiy
# Processing Record 26 of Set 6 | port augusta
# Processing Record 27 of Set 6 | roald
# Processing Record 28 of Set 6 | biak
# Processing Record 29 of Set 6 | santiago del estero
# Processing Record 30 of Set 6 | ilulissat
# Processing Record 31 of Set 6 | ladario
# Processing Record 32 of Set 6 | nanortalik
# Processing Record 33 of Set 6 | rabo de peixe
# Processing Record 34 of Set 6 | novouzensk
# Processing Record 35 of Set 6 | antsohihy
# Processing Record 36 of Set 6 | dzialdowo
# Processing Record 37 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 39 of Set 6 | juba
# Processing Record 40 of Set 6 | thinadhoo
# Processing Record 41 of Set 6 | takoradi
# Processing Record 42 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 6 | berbera
# Processing Record 44 of Set 6 | taltal
# Processing Record 45 of Set 6 | codrington
# Processing Record 46 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 6 | zhezkazgan
# Processing Record 48 of Set 6 | soavinandriana
# Processing Record 49 of Set 6 | villaviciosa
# Processing Record 50 of Set 6 | fortuna
# Processing Record 1 of Set 7 | nedjo
# Processing Record 2 of Set 7 | ahuimanu
# Processing Record 3 of Set 7 | qaqortoq
# Processing Record 4 of Set 7 | changping
# Processing Record 5 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 7 | nizhnevartovsk
# Processing Record 7 of Set 7 | santa fe
# Processing Record 8 of Set 7 | port hedland
# Processing Record 9 of Set 7 | rafai
# Processing Record 10 of Set 7 | sao filipe
# Processing Record 11 of Set 7 | romny
# Processing Record 12 of Set 7 | volga
# Processing Record 13 of Set 7 | katsuura
# Processing Record 14 of Set 7 | caravelas
# Processing Record 15 of Set 7 | fort nelson
# Processing Record 16 of Set 7 | torbay
# Processing Record 17 of Set 7 | ishinomaki
# Processing Record 18 of Set 7 | khani
# Processing Record 19 of Set 7 | tarko-sale
# Processing Record 20 of Set 7 | kamina
# Processing Record 21 of Set 7 | nelidovo
# Processing Record 22 of Set 7 | ahar
# Processing Record 23 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 7 | sawakin
# Processing Record 25 of Set 7 | kassala
# Processing Record 26 of Set 7 | madimba
# Processing Record 27 of Set 7 | hovd
# Processing Record 28 of Set 7 | arroyo
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | ejido
# Processing Record 31 of Set 7 | ambatondrazaka
# Processing Record 32 of Set 7 | saint-philippe
# Processing Record 33 of Set 7 | monrovia
# Processing Record 34 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 35 of Set 7 | chiang rai
# Processing Record 36 of Set 7 | samaipata
# Processing Record 37 of Set 7 | mahon
# Processing Record 38 of Set 7 | namibe
# Processing Record 39 of Set 7 | orlik
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | wanning
# Processing Record 42 of Set 7 | kushmurun
# Processing Record 43 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 44 of Set 7 | derzhavinsk
# Processing Record 45 of Set 7 | jalu
# Processing Record 46 of Set 7 | santa cruz
# Processing Record 47 of Set 7 | tomohon
# Processing Record 48 of Set 7 | lebu
# Processing Record 49 of Set 7 | elat
# Processing Record 50 of Set 7 | machiques
# Processing Record 1 of Set 8 | george town
# Processing Record 2 of Set 8 | cayenne
# Processing Record 3 of Set 8 | dong xoai
# Processing Record 4 of Set 8 | tiarei
# Processing Record 5 of Set 8 | sao joao da barra
# Processing Record 6 of Set 8 | ahipara
# Processing Record 7 of Set 8 | hualmay
# Processing Record 8 of Set 8 | tuatapere
# Processing Record 9 of Set 8 | agadir
# Processing Record 10 of Set 8 | berberati
# Processing Record 11 of Set 8 | coos bay
# Processing Record 12 of Set 8 | waki
# Processing Record 13 of Set 8 | tibati
# Processing Record 14 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 8 | aswan
# Processing Record 16 of Set 8 | gorontalo
# Processing Record 17 of Set 8 | asau
# Processing Record 18 of Set 8 | tabou
# Processing Record 19 of Set 8 | laguna
# Processing Record 20 of Set 8 | sioux lookout
# Processing Record 21 of Set 8 | majene
# Processing Record 22 of Set 8 | kletskaya
# Processing Record 23 of Set 8 | fayaoue
# Processing Record 24 of Set 8 | aberdeen
# Processing Record 25 of Set 8 | saint-ambroise
# Processing Record 26 of Set 8 | chulman
# Processing Record 27 of Set 8 | beloha
# Processing Record 28 of Set 8 | berezovyy
# Processing Record 29 of Set 8 | tuensang
# Processing Record 30 of Set 8 | burica
# City not found. Skipping...
# Processing Record 31 of Set 8 | yamada
# Processing Record 32 of Set 8 | sava
# Processing Record 33 of Set 8 | feldbach
# Processing Record 34 of Set 8 | kalat
# Processing Record 35 of Set 8 | tarabuco
# Processing Record 36 of Set 8 | tombouctou
# Processing Record 37 of Set 8 | lagoa
# Processing Record 38 of Set 8 | xiongshi
# City not found. Skipping...
# Processing Record 39 of Set 8 | barranca
# Processing Record 40 of Set 8 | dolzhanskaya
# Processing Record 41 of Set 8 | guerrero negro
# Processing Record 42 of Set 8 | mahebourg
# Processing Record 43 of Set 8 | jatai
# Processing Record 44 of Set 8 | grindavik
# Processing Record 45 of Set 8 | russkiy kameshkir
# Processing Record 46 of Set 8 | mareeba
# Processing Record 47 of Set 8 | tanout
# Processing Record 48 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | newport
# Processing Record 50 of Set 8 | sao miguel do araguaia
# Processing Record 1 of Set 9 | utica
# Processing Record 2 of Set 9 | luebo
# Processing Record 3 of Set 9 | sinop
# Processing Record 4 of Set 9 | nizhniy tsasuchey
# Processing Record 5 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 9 | glyadyanskoye
# Processing Record 7 of Set 9 | westport
# Processing Record 8 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 9 | bubaque
# Processing Record 11 of Set 9 | bhatkal
# Processing Record 12 of Set 9 | mwinilunga
# Processing Record 13 of Set 9 | gardner
# Processing Record 14 of Set 9 | griffith
# Processing Record 15 of Set 9 | skjervoy
# Processing Record 16 of Set 9 | klaksvik
# Processing Record 17 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 9 | kulhudhuffushi
# Processing Record 20 of Set 9 | tessalit
# Processing Record 21 of Set 9 | camacha
# Processing Record 22 of Set 9 | del rio
# Processing Record 23 of Set 9 | pandamatenga
# Processing Record 24 of Set 9 | cam ranh
# Processing Record 25 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 26 of Set 9 | saint-georges
# Processing Record 27 of Set 9 | kaohsiung
# Processing Record 28 of Set 9 | chapais
# Processing Record 29 of Set 9 | atikokan
# Processing Record 30 of Set 9 | lorengau
# Processing Record 31 of Set 9 | vengerovo
# Processing Record 32 of Set 9 | bend
# Processing Record 33 of Set 9 | kudahuvadhoo
# Processing Record 34 of Set 9 | srandakan
# Processing Record 35 of Set 9 | buchanan
# Processing Record 36 of Set 9 | ossora
# Processing Record 37 of Set 9 | sao joao do paraiso
# Processing Record 38 of Set 9 | ulaangom
# Processing Record 39 of Set 9 | rosario
# Processing Record 40 of Set 9 | doha
# Processing Record 41 of Set 9 | henties bay
# Processing Record 42 of Set 9 | buraydah
# Processing Record 43 of Set 9 | harstad
# Processing Record 44 of Set 9 | waingapu
# Processing Record 45 of Set 9 | trinidad
# Processing Record 46 of Set 9 | huarmey
# Processing Record 47 of Set 9 | karibib
# Processing Record 48 of Set 9 | morelia
# Processing Record 49 of Set 9 | mragowo
# Processing Record 50 of Set 9 | estelle
# Processing Record 1 of Set 10 | maragheh
# Processing Record 2 of Set 10 | zwedru
# Processing Record 3 of Set 10 | tabuk
# Processing Record 4 of Set 10 | poronaysk
# Processing Record 5 of Set 10 | mehamn
# Processing Record 6 of Set 10 | kasongo-lunda
# Processing Record 7 of Set 10 | puerto escondido
# Processing Record 8 of Set 10 | souillac
# Processing Record 9 of Set 10 | mocuba
# Processing Record 10 of Set 10 | pemangkat
# Processing Record 11 of Set 10 | paramonga
# Processing Record 12 of Set 10 | cururupu
# Processing Record 13 of Set 10 | puerto madryn
# Processing Record 14 of Set 10 | cap-aux-meules
# Processing Record 15 of Set 10 | chupei
# City not found. Skipping...
# Processing Record 16 of Set 10 | beringovskiy
# Processing Record 17 of Set 10 | new iberia
# Processing Record 18 of Set 10 | erenhot
# Processing Record 19 of Set 10 | besancon
# Processing Record 20 of Set 10 | uvira
# Processing Record 21 of Set 10 | cruzeiro do sul
# Processing Record 22 of Set 10 | olafsvik
# Processing Record 23 of Set 10 | mashhad
# Processing Record 24 of Set 10 | asyut
# Processing Record 25 of Set 10 | carutapera
# Processing Record 26 of Set 10 | half moon bay
# Processing Record 27 of Set 10 | semnan
# Processing Record 28 of Set 10 | zheleznodorozhnyy
# Processing Record 29 of Set 10 | artesia
# Processing Record 30 of Set 10 | los llanos de aridane
# Processing Record 31 of Set 10 | antalaha
# Processing Record 32 of Set 10 | slave lake
# Processing Record 33 of Set 10 | abomsa
# Processing Record 34 of Set 10 | aklavik
# Processing Record 35 of Set 10 | hun
# Processing Record 36 of Set 10 | olinda
# Processing Record 37 of Set 10 | sisimiut
# Processing Record 38 of Set 10 | tianpeng
# Processing Record 39 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 40 of Set 10 | emba
# Processing Record 41 of Set 10 | camana
# Processing Record 42 of Set 10 | dodoma
# Processing Record 43 of Set 10 | atherton
# Processing Record 44 of Set 10 | khandyga
# Processing Record 45 of Set 10 | guayabal
# Processing Record 46 of Set 10 | lanxi
# Processing Record 47 of Set 10 | namanga
# Processing Record 48 of Set 10 | navoi
# Processing Record 49 of Set 10 | yefimovskiy
# City not found. Skipping...
# Processing Record 50 of Set 10 | hamilton
# Processing Record 1 of Set 11 | norman wells
# Processing Record 2 of Set 11 | walvis bay
# Processing Record 3 of Set 11 | ubinskoye
# Processing Record 4 of Set 11 | cabo san lucas
# Processing Record 5 of Set 11 | tomatlan
# Processing Record 6 of Set 11 | ocala
# Processing Record 7 of Set 11 | san pedro
# Processing Record 8 of Set 11 | plettenberg bay
# Processing Record 9 of Set 11 | kindu
# Processing Record 10 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 11 | krasnoselkup
# Processing Record 12 of Set 11 | zyryanskoye
# Processing Record 13 of Set 11 | lensk
# Processing Record 14 of Set 11 | bulgan
# Processing Record 15 of Set 11 | sinnamary
# Processing Record 16 of Set 11 | matagami
# Processing Record 17 of Set 11 | karera
# Processing Record 18 of Set 11 | niwari
# Processing Record 19 of Set 11 | darnah
# Processing Record 20 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 11 | havelock
# Processing Record 22 of Set 11 | aykhal
# Processing Record 23 of Set 11 | gerash
# Processing Record 24 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 11 | bayir
# Processing Record 26 of Set 11 | sidi qasim
# City not found. Skipping...
# Processing Record 27 of Set 11 | jackson
# Processing Record 28 of Set 11 | boyuibe
# Processing Record 29 of Set 11 | mercedes
# Processing Record 30 of Set 11 | lamballe
# Processing Record 31 of Set 11 | mezen
# Processing Record 32 of Set 11 | nishihara
# Processing Record 33 of Set 11 | wembley
# Processing Record 34 of Set 11 | kenai
# Processing Record 35 of Set 11 | praia da vitoria
# Processing Record 36 of Set 11 | yinchuan
# Processing Record 37 of Set 11 | seinajoki
# Processing Record 38 of Set 11 | taoudenni
# Processing Record 39 of Set 11 | san andres
# Processing Record 40 of Set 11 | thiruvananthapuram
# Processing Record 41 of Set 11 | urumqi
# Processing Record 42 of Set 11 | kodinsk
# Processing Record 43 of Set 11 | vyartsilya
# Processing Record 44 of Set 11 | trojes
# Processing Record 45 of Set 11 | waipawa
# Processing Record 46 of Set 11 | vila do maio
# Processing Record 47 of Set 11 | sault sainte marie
# Processing Record 48 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 11 | ostrovnoy
# Processing Record 50 of Set 11 | antofagasta
# Processing Record 1 of Set 12 | bulawayo
# Processing Record 2 of Set 12 | alice springs
# Processing Record 3 of Set 12 | lukovo
# Processing Record 4 of Set 12 | nome
# Processing Record 5 of Set 12 | ust-maya
# Processing Record 6 of Set 12 | paka
# Processing Record 7 of Set 12 | padang
# Processing Record 8 of Set 12 | teknaf
# Processing Record 9 of Set 12 | kangaatsiaq
# Processing Record 10 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 12 | sungurlu
# Processing Record 12 of Set 12 | shchuchye
# City not found. Skipping...
# Processing Record 13 of Set 12 | muscat
# Processing Record 14 of Set 12 | lakatoro
# Processing Record 15 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 12 | sargatskoye
# Processing Record 17 of Set 12 | nuevo progreso
# Processing Record 18 of Set 12 | dwarka
# Processing Record 19 of Set 12 | birao
# Processing Record 20 of Set 12 | ruteng
# Processing Record 21 of Set 12 | emerald
# Processing Record 22 of Set 12 | moyale
# Processing Record 23 of Set 12 | dunedin
# Processing Record 24 of Set 12 | jardim
# Processing Record 25 of Set 12 | aksarka
# Processing Record 26 of Set 12 | alofi
# Processing Record 27 of Set 12 | aquiraz
# Processing Record 28 of Set 12 | garowe
# Processing Record 29 of Set 12 | saint anthony
# Processing Record 30 of Set 12 | opuwo
# Processing Record 31 of Set 12 | arauco
# Processing Record 32 of Set 12 | qasigiannguit
# Processing Record 33 of Set 12 | nadym
# Processing Record 34 of Set 12 | taybad
# Processing Record 35 of Set 12 | ngunguru
# Processing Record 36 of Set 12 | kosh-agach
# Processing Record 37 of Set 12 | guider
# Processing Record 38 of Set 12 | cerro largo
# Processing Record 39 of Set 12 | katete
# Processing Record 40 of Set 12 | gamba
# Processing Record 41 of Set 12 | mumford
# Processing Record 42 of Set 12 | santa maria
# Processing Record 43 of Set 12 | itarema
# Processing Record 44 of Set 12 | mustafakemalpasa
# Processing Record 45 of Set 12 | mwingi
# Processing Record 46 of Set 12 | pangody
# Processing Record 47 of Set 12 | kailua
# Processing Record 48 of Set 12 | tateyama
# Processing Record 49 of Set 12 | kochevo
# Processing Record 50 of Set 12 | belen
# Processing Record 1 of Set 13 | bertoua
# Processing Record 2 of Set 13 | gweru
# Processing Record 3 of Set 13 | ancud
# Processing Record 4 of Set 13 | egvekinot
# Processing Record 5 of Set 13 | liuhe
# Processing Record 6 of Set 13 | stonewall
# Processing Record 7 of Set 13 | ondjiva
# Processing Record 8 of Set 13 | passi
# Processing Record 9 of Set 13 | silveira
# Processing Record 10 of Set 13 | tautira
# Processing Record 11 of Set 13 | santa isabel do rio negro
# Processing Record 12 of Set 13 | zonguldak
# Processing Record 13 of Set 13 | laiyang
# Processing Record 14 of Set 13 | taksimo
# Processing Record 15 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 13 | alakurtti
# Processing Record 17 of Set 13 | ambulu
# Processing Record 18 of Set 13 | beisfjord
# Processing Record 19 of Set 13 | ushtobe
# Processing Record 20 of Set 13 | ermioni
# Processing Record 21 of Set 13 | sumbe
# Processing Record 22 of Set 13 | zhigansk
# Processing Record 23 of Set 13 | conceicao do araguaia
# Processing Record 24 of Set 13 | meadow lake
# Processing Record 25 of Set 13 | sayyan
# Processing Record 26 of Set 13 | pedernales
# Processing Record 27 of Set 13 | koungheul
# Processing Record 28 of Set 13 | levelland
# Processing Record 29 of Set 13 | marfino
# Processing Record 30 of Set 13 | santa barbara
# Processing Record 31 of Set 13 | stantsionno-oyashinskiy
# Processing Record 32 of Set 13 | manaus
# Processing Record 33 of Set 13 | genhe
# Processing Record 34 of Set 13 | vanavara
# Processing Record 35 of Set 13 | piacabucu
# Processing Record 36 of Set 13 | berdigestyakh
# Processing Record 37 of Set 13 | waddan
# Processing Record 38 of Set 13 | nebug
# Processing Record 39 of Set 13 | zelezna ruda
# Processing Record 40 of Set 13 | japura
# Processing Record 41 of Set 13 | deputatskiy
# Processing Record 42 of Set 13 | wuxue
# Processing Record 43 of Set 13 | cartagena
# Processing Record 44 of Set 13 | kilrush
# Processing Record 45 of Set 13 | mayo
# Processing Record 46 of Set 13 | sur
# Processing Record 47 of Set 13 | natchez
# Processing Record 48 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 13 | san quintin
# Processing Record 50 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 1 of Set 14 | yala
# Processing Record 2 of Set 14 | kiruna
# Processing Record 3 of Set 14 | takeo
# Processing Record 4 of Set 14 | hornepayne
# Processing Record 5 of Set 14 | santa rosalia
# Processing Record 6 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 8 of Set 14 | sao gabriel
# Processing Record 9 of Set 14 | selikhino
# Processing Record 10 of Set 14 | moerai
# Processing Record 11 of Set 14 | tucupita
# Processing Record 12 of Set 14 | zelenogradsk
# Processing Record 13 of Set 14 | wajima
# Processing Record 14 of Set 14 | maragogi
# Processing Record 15 of Set 14 | san vicente
# Processing Record 16 of Set 14 | coahuayana
# Processing Record 17 of Set 14 | terrace bay
# Processing Record 18 of Set 14 | bogashevo
# Processing Record 19 of Set 14 | chateau-thierry
# Processing Record 20 of Set 14 | jiaojiang
# Processing Record 21 of Set 14 | ivaipora
# Processing Record 22 of Set 14 | bahraich
# Processing Record 23 of Set 14 | oeiras
# Processing Record 24 of Set 14 | skibotn
# Processing Record 25 of Set 14 | san jeronimo
# Processing Record 26 of Set 14 | inverell
# Processing Record 27 of Set 14 | zyryanka
# Processing Record 28 of Set 14 | bombay
# Processing Record 29 of Set 14 | boa vista
# Processing Record 30 of Set 14 | kapoeta
# Processing Record 31 of Set 14 | road town
# Processing Record 32 of Set 14 | hazorasp
# Processing Record 33 of Set 14 | puerto leguizamo
# Processing Record 34 of Set 14 | hambantota
# Processing Record 35 of Set 14 | saint-francois
# Processing Record 36 of Set 14 | river falls
# Processing Record 37 of Set 14 | tarakan
# Processing Record 38 of Set 14 | abong mbang
# Processing Record 39 of Set 14 | asfi
# Processing Record 40 of Set 14 | noshiro
# Processing Record 41 of Set 14 | abha
# Processing Record 42 of Set 14 | labuhan
# Processing Record 43 of Set 14 | jega
# Processing Record 44 of Set 14 | tolaga bay
# Processing Record 45 of Set 14 | pacific grove
# Processing Record 46 of Set 14 | tura
# Processing Record 47 of Set 14 | prattville
# Processing Record 48 of Set 14 | solnechnyy
# Processing Record 49 of Set 14 | west odessa
# Processing Record 50 of Set 14 | leisure city
# Processing Record 1 of Set 15 | mumbwa
# Processing Record 2 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 3 of Set 15 | minas de oro
# Processing Record 4 of Set 15 | chichester
# Processing Record 5 of Set 15 | fourmies
# Processing Record 6 of Set 15 | maine-soroa
# Processing Record 7 of Set 15 | kavaratti
# Processing Record 8 of Set 15 | suntar
# Processing Record 9 of Set 15 | marquette
# Processing Record 10 of Set 15 | bogorodskoye
# Processing Record 11 of Set 15 | mirabad
# Processing Record 12 of Set 15 | uglegorsk
# Processing Record 13 of Set 15 | maniwaki
# Processing Record 14 of Set 15 | vestmannaeyjar
# Processing Record 15 of Set 15 | abu kamal
# Processing Record 16 of Set 15 | kamiiso
# Processing Record 17 of Set 15 | usinsk
# Processing Record 18 of Set 15 | rodino
# Processing Record 19 of Set 15 | ippy
# Processing Record 20 of Set 15 | kathmandu
# Processing Record 21 of Set 15 | husavik
# Processing Record 22 of Set 15 | rezekne
# Processing Record 23 of Set 15 | dawlatabad
# Processing Record 24 of Set 15 | caraballeda
# Processing Record 25 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 15 | mungwi
# Processing Record 27 of Set 15 | compostela
# Processing Record 28 of Set 15 | paita
# Processing Record 29 of Set 15 | vicar
# Processing Record 30 of Set 15 | baghdad
# Processing Record 31 of Set 15 | kambarka
# Processing Record 32 of Set 15 | carnot
# Processing Record 33 of Set 15 | pisco
# Processing Record 34 of Set 15 | perth
# Processing Record 35 of Set 15 | saint-augustin
# Processing Record 36 of Set 15 | ventspils
# Processing Record 37 of Set 15 | kamogata
# Processing Record 38 of Set 15 | winnemucca
# Processing Record 39 of Set 15 | hervey bay
# Processing Record 40 of Set 15 | arlit
# Processing Record 41 of Set 15 | turukhansk
# Processing Record 42 of Set 15 | angoche
# Processing Record 43 of Set 15 | yanam
# Processing Record 44 of Set 15 | pilao arcado
# City not found. Skipping...
# Processing Record 45 of Set 15 | kirakira
# Processing Record 46 of Set 15 | portland
# Processing Record 47 of Set 15 | rezina
# Processing Record 48 of Set 15 | mount gambier
# Processing Record 49 of Set 15 | lagos
# Processing Record 50 of Set 15 | agadez
# Processing Record 1 of Set 16 | melipilla
# Processing Record 2 of Set 16 | kutum
# Processing Record 3 of Set 16 | bodden town
# Processing Record 4 of Set 16 | margate
# Processing Record 5 of Set 16 | kaseda
# Processing Record 6 of Set 16 | tadine
# Processing Record 7 of Set 16 | dongzhen
# Processing Record 8 of Set 16 | bossangoa
# Processing Record 9 of Set 16 | oliveira
# Processing Record 10 of Set 16 | zhangjiakou
# Processing Record 11 of Set 16 | nanakuli
# Processing Record 12 of Set 16 | mandalgovi
# Processing Record 13 of Set 16 | stephenville crossing
# Processing Record 14 of Set 16 | calabozo
# Processing Record 15 of Set 16 | shimsk
# Processing Record 16 of Set 16 | bethanien
# Processing Record 17 of Set 16 | baruun-urt
# Processing Record 18 of Set 16 | imbituba
# Processing Record 19 of Set 16 | ban phai
# Processing Record 20 of Set 16 | halifax
# Processing Record 21 of Set 16 | bo rai
# Processing Record 22 of Set 16 | khasan
# Processing Record 23 of Set 16 | tanggu
# Processing Record 24 of Set 16 | pierre
# Processing Record 25 of Set 16 | parana
# Processing Record 26 of Set 16 | vrede
# Processing Record 27 of Set 16 | saint-joseph
# Processing Record 28 of Set 16 | palmerston
# Processing Record 29 of Set 16 | barcelona
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 719

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Eureka      US  40.8021 -124.1637     57.67        88          88
# 1      Mataura      NZ -46.1927  168.8643     62.20        73           8
# 2       Pavino      RU  59.1139   46.1414      3.96       100          90
# 3     San Juan      AR -31.5375  -68.5364     83.43        18           0
# 4  Pangnirtung      CA  66.1451  -65.7125     19.40        79         100
#
#    Wind Speed Current Description
# 0       10.00     overcast clouds
# 1        1.45           clear sky
# 2        3.74     overcast clouds
# 3       29.53           clear sky
# 4        3.44     overcast clouds

# %%
city_data_df.to_csv(r'C:\Users\lag86\OneDrive\Desktop\BOOTCAMP STUFF\Asynchronous---Challenge\Module 6 - APIs\World_Weather_Analysis- clone\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv')
