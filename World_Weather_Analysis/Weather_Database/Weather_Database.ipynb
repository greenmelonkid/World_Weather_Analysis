# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 738

# %%
import requests

from config import weather_api_key

import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f3a2560397bcadb7f1af3b16b263bffe

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
#city_data = []

# Print the beginning of the logging.
#print("Beginning Data Retrieval    ")
#print("----------------------------")

# Create counters.
#record_count = 1
#set_count = 1

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
       

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
   
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_des = city_weather["weather"][0]["description"]
          
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_des})    
     


    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | yalta
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | chake chake
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | omboue
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | caravelas
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | gondanglegi
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | lorengau
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | cabo san lucas
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | kudahuvadhoo
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | da nang
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | kavieng
# Processing Record 27 of Set 1 | vernon
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | manyana
# Processing Record 30 of Set 1 | timmendorfer strand
# Processing Record 31 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | casper
# Processing Record 34 of Set 1 | varkkallai
# Processing Record 35 of Set 1 | terrace
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | tanete
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | collecchio
# Processing Record 44 of Set 1 | nemuro
# Processing Record 45 of Set 1 | vanimo
# Processing Record 46 of Set 1 | bahraich
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | grafenhainichen
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | syamzha
# Processing Record 2 of Set 2 | airai
# Processing Record 3 of Set 2 | ranau
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | le vauclin
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | alappuzha
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | avera
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | husavik
# Processing Record 14 of Set 2 | san francisco
# Processing Record 15 of Set 2 | guangyuan
# Processing Record 16 of Set 2 | veraval
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | salvador
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | nome
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | dunedin
# Processing Record 24 of Set 2 | lastoursville
# Processing Record 25 of Set 2 | santa ana
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | tubuala
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | hays
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | kurumkan
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | maniitsoq
# Processing Record 38 of Set 2 | manggar
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | pa sang
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | lyndon
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | guerrero negro
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | luanda
# Processing Record 49 of Set 2 | pangnirtung
# Processing Record 50 of Set 2 | mao
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | huazolotitlan
# City not found. Skipping...
# Processing Record 3 of Set 3 | concepcion del oro
# Processing Record 4 of Set 3 | la peca
# Processing Record 5 of Set 3 | chicama
# Processing Record 6 of Set 3 | yishui
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | okhotsk
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | mount gambier
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | geraldton
# Processing Record 13 of Set 3 | codrington
# Processing Record 14 of Set 3 | kuntaur
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | severo-kurilsk
# Processing Record 17 of Set 3 | sohag
# Processing Record 18 of Set 3 | uzhur
# Processing Record 19 of Set 3 | abha
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | phonhong
# Processing Record 22 of Set 3 | bangkalan
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | mahibadhoo
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | tatawin
# Processing Record 30 of Set 3 | krasnoselkup
# Processing Record 31 of Set 3 | lasa
# Processing Record 32 of Set 3 | hay river
# Processing Record 33 of Set 3 | tazovskiy
# Processing Record 34 of Set 3 | huntington
# Processing Record 35 of Set 3 | petropavl
# Processing Record 36 of Set 3 | port macquarie
# Processing Record 37 of Set 3 | talaya
# Processing Record 38 of Set 3 | port lincoln
# Processing Record 39 of Set 3 | chiang rai
# Processing Record 40 of Set 3 | xining
# Processing Record 41 of Set 3 | poya
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | cabedelo
# Processing Record 44 of Set 3 | odweyne
# Processing Record 45 of Set 3 | saint-philippe
# Processing Record 46 of Set 3 | cascais
# Processing Record 47 of Set 3 | grand gaube
# Processing Record 48 of Set 3 | seondha
# Processing Record 49 of Set 3 | cayenne
# Processing Record 50 of Set 3 | shanghai
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | venado tuerto
# Processing Record 3 of Set 4 | guajara-mirim
# City not found. Skipping...
# Processing Record 4 of Set 4 | hithadhoo
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | sinop
# Processing Record 7 of Set 4 | roald
# Processing Record 8 of Set 4 | coahuayana
# Processing Record 9 of Set 4 | zapolyarnyy
# Processing Record 10 of Set 4 | vila franca do campo
# Processing Record 11 of Set 4 | namanga
# Processing Record 12 of Set 4 | komsomolskiy
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | tver
# Processing Record 15 of Set 4 | shizunai
# Processing Record 16 of Set 4 | ugoofaaru
# Processing Record 17 of Set 4 | taoudenni
# Processing Record 18 of Set 4 | harnosand
# Processing Record 19 of Set 4 | bathsheba
# Processing Record 20 of Set 4 | comodoro rivadavia
# Processing Record 21 of Set 4 | russell
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | turukhansk
# Processing Record 24 of Set 4 | bac lieu
# Processing Record 25 of Set 4 | salalah
# Processing Record 26 of Set 4 | kysyl-syr
# Processing Record 27 of Set 4 | charlottetown
# Processing Record 28 of Set 4 | sylvania
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | myrtle beach
# Processing Record 31 of Set 4 | novaya ladoga
# Processing Record 32 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 4 | kidal
# Processing Record 34 of Set 4 | vestmannaeyjar
# Processing Record 35 of Set 4 | forest
# Processing Record 36 of Set 4 | te anau
# Processing Record 37 of Set 4 | revda
# Processing Record 38 of Set 4 | oschatz
# Processing Record 39 of Set 4 | boatlaname
# City not found. Skipping...
# Processing Record 40 of Set 4 | gravelbourg
# Processing Record 41 of Set 4 | abalak
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | anloga
# Processing Record 45 of Set 4 | khandyga
# Processing Record 46 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 47 of Set 4 | constantine
# Processing Record 48 of Set 4 | pisco
# Processing Record 49 of Set 4 | port keats
# Processing Record 50 of Set 4 | umm lajj
# Processing Record 1 of Set 5 | sao joao da barra
# Processing Record 2 of Set 5 | isangel
# Processing Record 3 of Set 5 | dakar
# Processing Record 4 of Set 5 | ahuimanu
# Processing Record 5 of Set 5 | aksu
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | guanica
# Processing Record 8 of Set 5 | sao filipe
# Processing Record 9 of Set 5 | waipawa
# Processing Record 10 of Set 5 | norman wells
# Processing Record 11 of Set 5 | atasu
# Processing Record 12 of Set 5 | shingu
# Processing Record 13 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 5 | kodiak
# Processing Record 15 of Set 5 | worland
# Processing Record 16 of Set 5 | kantunilkin
# Processing Record 17 of Set 5 | paramonga
# Processing Record 18 of Set 5 | venice
# Processing Record 19 of Set 5 | seabra
# Processing Record 20 of Set 5 | marsa matruh
# Processing Record 21 of Set 5 | faya
# Processing Record 22 of Set 5 | wewak
# Processing Record 23 of Set 5 | fergus falls
# Processing Record 24 of Set 5 | yumen
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | biak
# Processing Record 27 of Set 5 | prince rupert
# Processing Record 28 of Set 5 | navalmoral de la mata
# Processing Record 29 of Set 5 | pindi bhattian
# Processing Record 30 of Set 5 | virginia beach
# Processing Record 31 of Set 5 | olga
# Processing Record 32 of Set 5 | san quintin
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | ribeira grande
# Processing Record 36 of Set 5 | oktyabrskoye
# Processing Record 37 of Set 5 | asau
# Processing Record 38 of Set 5 | oliver
# Processing Record 39 of Set 5 | shakawe
# Processing Record 40 of Set 5 | mudgee
# Processing Record 41 of Set 5 | kristiansund
# Processing Record 42 of Set 5 | aswan
# Processing Record 43 of Set 5 | kropachevo
# Processing Record 44 of Set 5 | juruti
# Processing Record 45 of Set 5 | gavle
# Processing Record 46 of Set 5 | storforshei
# Processing Record 47 of Set 5 | egvekinot
# Processing Record 48 of Set 5 | adrar
# Processing Record 49 of Set 5 | hambantota
# Processing Record 50 of Set 5 | esil
# Processing Record 1 of Set 6 | abriaqui
# Processing Record 2 of Set 6 | wiarton
# Processing Record 3 of Set 6 | grasten
# Processing Record 4 of Set 6 | dwarka
# Processing Record 5 of Set 6 | yasnyy
# Processing Record 6 of Set 6 | bethel
# Processing Record 7 of Set 6 | hostotipaquillo
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | tsumeb
# Processing Record 11 of Set 6 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | kathu
# Processing Record 13 of Set 6 | tocopilla
# Processing Record 14 of Set 6 | kununurra
# Processing Record 15 of Set 6 | barra do garcas
# Processing Record 16 of Set 6 | avarua
# Processing Record 17 of Set 6 | coquimbo
# Processing Record 18 of Set 6 | clyde river
# Processing Record 19 of Set 6 | stokmarknes
# Processing Record 20 of Set 6 | rundu
# Processing Record 21 of Set 6 | sharanga
# Processing Record 22 of Set 6 | hailey
# Processing Record 23 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 24 of Set 6 | santa cruz
# Processing Record 25 of Set 6 | guozhen
# Processing Record 26 of Set 6 | ketchikan
# Processing Record 27 of Set 6 | broome
# Processing Record 28 of Set 6 | kavaratti
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | alamosa
# Processing Record 31 of Set 6 | flin flon
# Processing Record 32 of Set 6 | nanortalik
# Processing Record 33 of Set 6 | gamba
# Processing Record 34 of Set 6 | nizwa
# Processing Record 35 of Set 6 | srednekolymsk
# Processing Record 36 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 6 | fairbanks
# Processing Record 38 of Set 6 | guaruja
# Processing Record 39 of Set 6 | wuwei
# Processing Record 40 of Set 6 | tikrit
# Processing Record 41 of Set 6 | tucuman
# Processing Record 42 of Set 6 | linjiang
# Processing Record 43 of Set 6 | havre-saint-pierre
# Processing Record 44 of Set 6 | tandalti
# Processing Record 45 of Set 6 | rosarito
# Processing Record 46 of Set 6 | ciudad bolivar
# Processing Record 47 of Set 6 | gairo
# Processing Record 48 of Set 6 | kahului
# Processing Record 49 of Set 6 | kualakapuas
# Processing Record 50 of Set 6 | pestretsy
# Processing Record 1 of Set 7 | asbe teferi
# Processing Record 2 of Set 7 | royton
# Processing Record 3 of Set 7 | palmer
# Processing Record 4 of Set 7 | san luis
# Processing Record 5 of Set 7 | polunochnoye
# Processing Record 6 of Set 7 | sydney
# Processing Record 7 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 8 of Set 7 | ilulissat
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | oloron-sainte-marie
# Processing Record 11 of Set 7 | severnyy
# Processing Record 12 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 13 of Set 7 | saldanha
# Processing Record 14 of Set 7 | bontang
# Processing Record 15 of Set 7 | talnakh
# Processing Record 16 of Set 7 | mujiayingzi
# Processing Record 17 of Set 7 | hohhot
# Processing Record 18 of Set 7 | westport
# Processing Record 19 of Set 7 | padang
# Processing Record 20 of Set 7 | vao
# Processing Record 21 of Set 7 | dinkelsbuhl
# Processing Record 22 of Set 7 | saint-leu
# Processing Record 23 of Set 7 | akureyri
# Processing Record 24 of Set 7 | mbacke
# City not found. Skipping...
# Processing Record 25 of Set 7 | kirakira
# Processing Record 26 of Set 7 | nalut
# Processing Record 27 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 7 | hun
# Processing Record 29 of Set 7 | constitucion
# Processing Record 30 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 7 | samarai
# Processing Record 32 of Set 7 | buala
# Processing Record 33 of Set 7 | goderich
# Processing Record 34 of Set 7 | ucluelet
# Processing Record 35 of Set 7 | kadnikov
# Processing Record 36 of Set 7 | lakhnadon
# Processing Record 37 of Set 7 | urcos
# Processing Record 38 of Set 7 | thompson
# Processing Record 39 of Set 7 | maceio
# Processing Record 40 of Set 7 | lavrentiya
# Processing Record 41 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 42 of Set 7 | ciechanow
# Processing Record 43 of Set 7 | beloha
# Processing Record 44 of Set 7 | andenes
# Processing Record 45 of Set 7 | bonavista
# Processing Record 46 of Set 7 | urumqi
# Processing Record 47 of Set 7 | alofi
# Processing Record 48 of Set 7 | karakol
# Processing Record 49 of Set 7 | bengkulu
# Processing Record 50 of Set 7 | faanui
# Processing Record 1 of Set 8 | la ronge
# Processing Record 2 of Set 8 | erzurum
# Processing Record 3 of Set 8 | marrakesh
# Processing Record 4 of Set 8 | raska
# Processing Record 5 of Set 8 | kalmunai
# Processing Record 6 of Set 8 | kintampo
# Processing Record 7 of Set 8 | lillooet
# Processing Record 8 of Set 8 | richards bay
# Processing Record 9 of Set 8 | sisophon
# Processing Record 10 of Set 8 | maiduguri
# Processing Record 11 of Set 8 | karratha
# Processing Record 12 of Set 8 | praia da vitoria
# Processing Record 13 of Set 8 | moyale
# Processing Record 14 of Set 8 | gondar
# Processing Record 15 of Set 8 | porto santo
# Processing Record 16 of Set 8 | florence
# Processing Record 17 of Set 8 | misratah
# Processing Record 18 of Set 8 | sambava
# Processing Record 19 of Set 8 | ternate
# Processing Record 20 of Set 8 | wattegama
# Processing Record 21 of Set 8 | moose factory
# Processing Record 22 of Set 8 | orlik
# Processing Record 23 of Set 8 | batagay-alyta
# Processing Record 24 of Set 8 | nanticoke
# Processing Record 25 of Set 8 | jishou
# Processing Record 26 of Set 8 | bowen
# Processing Record 27 of Set 8 | sept-iles
# Processing Record 28 of Set 8 | sterling
# Processing Record 29 of Set 8 | lagoa
# Processing Record 30 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 8 | komsomolets
# Processing Record 32 of Set 8 | nanakuli
# Processing Record 33 of Set 8 | darab
# Processing Record 34 of Set 8 | baijiantan
# Processing Record 35 of Set 8 | mana
# Processing Record 36 of Set 8 | moen
# Processing Record 37 of Set 8 | upernavik
# Processing Record 38 of Set 8 | tura
# Processing Record 39 of Set 8 | poum
# Processing Record 40 of Set 8 | high prairie
# Processing Record 41 of Set 8 | yenagoa
# Processing Record 42 of Set 8 | srivardhan
# Processing Record 43 of Set 8 | yar-sale
# Processing Record 44 of Set 8 | aykhal
# Processing Record 45 of Set 8 | itaituba
# Processing Record 46 of Set 8 | suicheng
# Processing Record 47 of Set 8 | karlshamn
# Processing Record 48 of Set 8 | arlit
# Processing Record 49 of Set 8 | elat
# Processing Record 50 of Set 8 | rocha
# Processing Record 1 of Set 9 | kashi
# Processing Record 2 of Set 9 | nhulunbuy
# Processing Record 3 of Set 9 | byron bay
# Processing Record 4 of Set 9 | yulara
# Processing Record 5 of Set 9 | rochester
# Processing Record 6 of Set 9 | axim
# Processing Record 7 of Set 9 | kurilsk
# Processing Record 8 of Set 9 | yusva
# City not found. Skipping...
# Processing Record 9 of Set 9 | changli
# Processing Record 10 of Set 9 | iqaluit
# Processing Record 11 of Set 9 | boddam
# Processing Record 12 of Set 9 | salta
# Processing Record 13 of Set 9 | marawi
# Processing Record 14 of Set 9 | dongargaon
# Processing Record 15 of Set 9 | cheyenne
# Processing Record 16 of Set 9 | port hedland
# Processing Record 17 of Set 9 | gornopravdinsk
# Processing Record 18 of Set 9 | cheremshan
# Processing Record 19 of Set 9 | norrtalje
# Processing Record 20 of Set 9 | camacha
# Processing Record 21 of Set 9 | carlyle
# Processing Record 22 of Set 9 | meulaboh
# Processing Record 23 of Set 9 | jalu
# Processing Record 24 of Set 9 | kalur kot
# Processing Record 25 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 9 | henties bay
# Processing Record 28 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 29 of Set 9 | ibb
# Processing Record 30 of Set 9 | soc trang
# Processing Record 31 of Set 9 | bonthe
# Processing Record 32 of Set 9 | moree
# Processing Record 33 of Set 9 | quartucciu
# Processing Record 34 of Set 9 | changping
# Processing Record 35 of Set 9 | dudinka
# Processing Record 36 of Set 9 | katsuura
# Processing Record 37 of Set 9 | saint-pierre
# Processing Record 38 of Set 9 | roma
# Processing Record 39 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 9 | labytnangi
# Processing Record 41 of Set 9 | merritt island
# Processing Record 42 of Set 9 | sines
# Processing Record 43 of Set 9 | shenjiamen
# Processing Record 44 of Set 9 | busembatia
# Processing Record 45 of Set 9 | rurrenabaque
# Processing Record 46 of Set 9 | ahipara
# Processing Record 47 of Set 9 | los banos
# Processing Record 48 of Set 9 | dubbo
# Processing Record 49 of Set 9 | cabo rojo
# Processing Record 50 of Set 9 | ormara
# Processing Record 1 of Set 10 | harper
# Processing Record 2 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 10 | vichy
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | rudsar
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | tomatlan
# Processing Record 8 of Set 10 | mathathane
# Processing Record 9 of Set 10 | bocas del toro
# Processing Record 10 of Set 10 | cotonou
# Processing Record 11 of Set 10 | cocachacra
# Processing Record 12 of Set 10 | plattling
# Processing Record 13 of Set 10 | bandarbeyla
# Processing Record 14 of Set 10 | sal rei
# Processing Record 15 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 10 | klaksvik
# Processing Record 17 of Set 10 | palembang
# Processing Record 18 of Set 10 | charleston
# Processing Record 19 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 10 | asfi
# Processing Record 22 of Set 10 | joshimath
# Processing Record 23 of Set 10 | los llanos de aridane
# Processing Record 24 of Set 10 | dicabisagan
# Processing Record 25 of Set 10 | asyut
# Processing Record 26 of Set 10 | ornskoldsvik
# Processing Record 27 of Set 10 | pacific grove
# Processing Record 28 of Set 10 | todos santos
# Processing Record 29 of Set 10 | jumilla
# Processing Record 30 of Set 10 | walvis bay
# Processing Record 31 of Set 10 | fare
# Processing Record 32 of Set 10 | livani
# Processing Record 33 of Set 10 | logan
# Processing Record 34 of Set 10 | junin
# Processing Record 35 of Set 10 | salinas
# Processing Record 36 of Set 10 | jieshi
# Processing Record 37 of Set 10 | bakel
# Processing Record 38 of Set 10 | chikwawa
# Processing Record 39 of Set 10 | evensk
# Processing Record 40 of Set 10 | linxia
# Processing Record 41 of Set 10 | sisimiut
# Processing Record 42 of Set 10 | izmit
# Processing Record 43 of Set 10 | verkhnevilyuysk
# Processing Record 44 of Set 10 | midland
# Processing Record 45 of Set 10 | itarema
# Processing Record 46 of Set 10 | nabire
# Processing Record 47 of Set 10 | astana
# Processing Record 48 of Set 10 | vetralla
# Processing Record 49 of Set 10 | soto la marina
# Processing Record 50 of Set 10 | kushmurun
# Processing Record 1 of Set 11 | erzincan
# Processing Record 2 of Set 11 | labuhan
# Processing Record 3 of Set 11 | surt
# Processing Record 4 of Set 11 | belluru
# Processing Record 5 of Set 11 | alta floresta
# Processing Record 6 of Set 11 | maningrida
# Processing Record 7 of Set 11 | bettiah
# Processing Record 8 of Set 11 | mlonggo
# Processing Record 9 of Set 11 | vanavara
# Processing Record 10 of Set 11 | zhuhai
# Processing Record 11 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 11 | nantucket
# Processing Record 13 of Set 11 | college
# Processing Record 14 of Set 11 | rio grande
# Processing Record 15 of Set 11 | cape elizabeth
# City not found. Skipping...
# Processing Record 16 of Set 11 | isoka
# Processing Record 17 of Set 11 | miraflores
# Processing Record 18 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 11 | ostersund
# Processing Record 20 of Set 11 | burnie
# Processing Record 21 of Set 11 | innisfail
# Processing Record 22 of Set 11 | villa maria
# Processing Record 23 of Set 11 | koslan
# Processing Record 24 of Set 11 | alyangula
# Processing Record 25 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 11 | coos bay
# Processing Record 27 of Set 11 | akdepe
# Processing Record 28 of Set 11 | half moon bay
# Processing Record 29 of Set 11 | columbus
# Processing Record 30 of Set 11 | antofagasta
# Processing Record 31 of Set 11 | umea
# Processing Record 32 of Set 11 | benguela
# Processing Record 33 of Set 11 | zhangye
# Processing Record 34 of Set 11 | dindori
# Processing Record 35 of Set 11 | santa maria
# Processing Record 36 of Set 11 | port hardy
# Processing Record 37 of Set 11 | dingle
# Processing Record 38 of Set 11 | sistranda
# Processing Record 39 of Set 11 | aberystwyth
# Processing Record 40 of Set 11 | martapura
# Processing Record 41 of Set 11 | grindavik
# Processing Record 42 of Set 11 | qingan
# City not found. Skipping...
# Processing Record 43 of Set 11 | sucua
# Processing Record 44 of Set 11 | chapais
# Processing Record 45 of Set 11 | bembereke
# Processing Record 46 of Set 11 | dracena
# Processing Record 47 of Set 11 | rio gallegos
# Processing Record 48 of Set 11 | luzilandia
# Processing Record 49 of Set 11 | dong hoi
# Processing Record 50 of Set 11 | peace river
# Processing Record 1 of Set 12 | touros
# Processing Record 2 of Set 12 | dedza
# Processing Record 3 of Set 12 | puerto baquerizo moreno
# Processing Record 4 of Set 12 | lerwick
# Processing Record 5 of Set 12 | malkangiri
# Processing Record 6 of Set 12 | solnechnyy
# Processing Record 7 of Set 12 | priiskovyy
# Processing Record 8 of Set 12 | mweka
# Processing Record 9 of Set 12 | pleshanovo
# Processing Record 10 of Set 12 | quatre cocos
# Processing Record 11 of Set 12 | basco
# Processing Record 12 of Set 12 | atar
# Processing Record 13 of Set 12 | great bend
# Processing Record 14 of Set 12 | yerbogachen
# Processing Record 15 of Set 12 | betera
# Processing Record 16 of Set 12 | isla mujeres
# Processing Record 17 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 12 | honningsvag
# Processing Record 19 of Set 12 | ancud
# Processing Record 20 of Set 12 | sorland
# Processing Record 21 of Set 12 | yabelo
# Processing Record 22 of Set 12 | lancut
# Processing Record 23 of Set 12 | inhambane
# Processing Record 24 of Set 12 | berlevag
# Processing Record 25 of Set 12 | kuusamo
# Processing Record 26 of Set 12 | hobyo
# Processing Record 27 of Set 12 | san cristobal
# Processing Record 28 of Set 12 | ryomgard
# Processing Record 29 of Set 12 | muzhi
# Processing Record 30 of Set 12 | haines junction
# Processing Record 31 of Set 12 | ust-kuyga
# Processing Record 32 of Set 12 | hirara
# Processing Record 33 of Set 12 | maragogi
# Processing Record 34 of Set 12 | pyaozerskiy
# Processing Record 35 of Set 12 | ulaanbaatar
# Processing Record 36 of Set 12 | khasan
# Processing Record 37 of Set 12 | butterworth
# Processing Record 38 of Set 12 | mitu
# Processing Record 39 of Set 12 | qazax
# Processing Record 40 of Set 12 | ploemeur
# Processing Record 41 of Set 12 | novoagansk
# Processing Record 42 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 43 of Set 12 | livny
# Processing Record 44 of Set 12 | bestobe
# Processing Record 45 of Set 12 | halifax
# Processing Record 46 of Set 12 | yamada
# Processing Record 47 of Set 12 | methoni
# Processing Record 48 of Set 12 | black river
# Processing Record 49 of Set 12 | champerico
# Processing Record 50 of Set 12 | san vicente
# Processing Record 1 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 2 of Set 13 | rehoboth
# Processing Record 3 of Set 13 | rudnya
# Processing Record 4 of Set 13 | mwingi
# Processing Record 5 of Set 13 | saint george
# Processing Record 6 of Set 13 | mirnyy
# Processing Record 7 of Set 13 | akhalgori
# Processing Record 8 of Set 13 | bagotville
# Processing Record 9 of Set 13 | novobirilyussy
# Processing Record 10 of Set 13 | narasannapeta
# Processing Record 11 of Set 13 | the pas
# Processing Record 12 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 13 | cap malheureux
# Processing Record 14 of Set 13 | hualmay
# Processing Record 15 of Set 13 | maxixe
# Processing Record 16 of Set 13 | kotka
# Processing Record 17 of Set 13 | svetlyy
# Processing Record 18 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 13 | nuuk
# Processing Record 20 of Set 13 | madisonville
# Processing Record 21 of Set 13 | sola
# Processing Record 22 of Set 13 | katherine
# Processing Record 23 of Set 13 | agucadoura
# Processing Record 24 of Set 13 | vagur
# Processing Record 25 of Set 13 | wanning
# Processing Record 26 of Set 13 | iquitos
# Processing Record 27 of Set 13 | raga
# Processing Record 28 of Set 13 | ellensburg
# Processing Record 29 of Set 13 | port-cartier
# Processing Record 30 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 13 | skjeberg
# Processing Record 32 of Set 13 | waingapu
# Processing Record 33 of Set 13 | mandurah
# Processing Record 34 of Set 13 | yerofey pavlovich
# Processing Record 35 of Set 13 | yarada
# Processing Record 36 of Set 13 | kralendijk
# Processing Record 37 of Set 13 | riviere-au-renard
# Processing Record 38 of Set 13 | coihaique
# Processing Record 39 of Set 13 | kabompo
# Processing Record 40 of Set 13 | lar gerd
# City not found. Skipping...
# Processing Record 41 of Set 13 | pogar
# Processing Record 42 of Set 13 | bud
# Processing Record 43 of Set 13 | nizhnedevitsk
# Processing Record 44 of Set 13 | soure
# Processing Record 45 of Set 13 | chaman
# Processing Record 46 of Set 13 | vikhorevka
# Processing Record 47 of Set 13 | teacapan
# Processing Record 48 of Set 13 | weihe
# Processing Record 49 of Set 13 | sao jose da coroa grande
# Processing Record 50 of Set 13 | edd
# Processing Record 1 of Set 14 | udachnyy
# Processing Record 2 of Set 14 | oistins
# Processing Record 3 of Set 14 | kutum
# Processing Record 4 of Set 14 | batemans bay
# Processing Record 5 of Set 14 | trelew
# Processing Record 6 of Set 14 | tanshui
# City not found. Skipping...
# Processing Record 7 of Set 14 | poshekhonye
# Processing Record 8 of Set 14 | bilhaur
# Processing Record 9 of Set 14 | bubaque
# Processing Record 10 of Set 14 | campbell river
# Processing Record 11 of Set 14 | kattivakkam
# Processing Record 12 of Set 14 | pampa
# Processing Record 13 of Set 14 | tuatapere
# Processing Record 14 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 15 of Set 14 | havoysund
# Processing Record 16 of Set 14 | witu
# Processing Record 17 of Set 14 | auki
# Processing Record 18 of Set 14 | baft
# Processing Record 19 of Set 14 | guia lopes da laguna
# Processing Record 20 of Set 14 | sobolevo
# Processing Record 21 of Set 14 | cockburn town
# Processing Record 22 of Set 14 | briancon
# Processing Record 23 of Set 14 | diphu
# Processing Record 24 of Set 14 | rafaela
# Processing Record 25 of Set 14 | wapi pathum
# Processing Record 26 of Set 14 | lichuan
# Processing Record 27 of Set 14 | lolodorf
# Processing Record 28 of Set 14 | ferrol
# Processing Record 29 of Set 14 | jiaozuo
# Processing Record 30 of Set 14 | sonoita
# Processing Record 31 of Set 14 | maarianhamina
# Processing Record 32 of Set 14 | banda aceh
# Processing Record 33 of Set 14 | vardo
# Processing Record 34 of Set 14 | seoul
# Processing Record 35 of Set 14 | mogadishu
# Processing Record 36 of Set 14 | bridgetown
# Processing Record 37 of Set 14 | antalaha
# Processing Record 38 of Set 14 | anadyr
# Processing Record 39 of Set 14 | tessalit
# Processing Record 40 of Set 14 | deputatskiy
# Processing Record 41 of Set 14 | namatanai
# Processing Record 42 of Set 14 | kenora
# Processing Record 43 of Set 14 | umiray
# Processing Record 44 of Set 14 | abu dhabi
# Processing Record 45 of Set 14 | fortuna
# Processing Record 46 of Set 14 | suruc
# Processing Record 47 of Set 14 | calbuco
# Processing Record 48 of Set 14 | is
# City not found. Skipping...
# Processing Record 49 of Set 14 | dharchula
# Processing Record 50 of Set 14 | neiafu
# Processing Record 1 of Set 15 | ukiah
# Processing Record 2 of Set 15 | zunyi
# Processing Record 3 of Set 15 | lagodekhi
# Processing Record 4 of Set 15 | paamiut
# Processing Record 5 of Set 15 | radenci
# Processing Record 6 of Set 15 | sur
# Processing Record 7 of Set 15 | kyzyl
# Processing Record 8 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 15 | kunda
# Processing Record 10 of Set 15 | carepa
# Processing Record 11 of Set 15 | totness
# Processing Record 12 of Set 15 | kuzedeyevo
# Processing Record 13 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 15 | llangefni
# Processing Record 15 of Set 15 | lensk
# Processing Record 16 of Set 15 | ljungby
# Processing Record 17 of Set 15 | abu kamal
# Processing Record 18 of Set 15 | danielskuil
# Processing Record 19 of Set 15 | cairns
# Processing Record 20 of Set 15 | erdenet
# Processing Record 21 of Set 15 | atyrau
# Processing Record 22 of Set 15 | sioux lookout
# Processing Record 23 of Set 15 | havelock
# Processing Record 24 of Set 15 | deer lake
# Processing Record 25 of Set 15 | magistralnyy
# Processing Record 26 of Set 15 | kamenka
# Processing Record 27 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 28 of Set 15 | acarau
# Processing Record 29 of Set 15 | fairlie
# Processing Record 30 of Set 15 | chase
# Processing Record 31 of Set 15 | bloomfield
# Processing Record 32 of Set 15 | kodinsk
# Processing Record 33 of Set 15 | san policarpo
# Processing Record 34 of Set 15 | manokwari
# Processing Record 35 of Set 15 | shitanjing
# Processing Record 36 of Set 15 | taltal
# Processing Record 37 of Set 15 | manakara
# Processing Record 38 of Set 15 | gabi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 683

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Yalta      UA  44.5000   34.1667     44.62        66          13
# 1      Qaanaaq      GL  77.4840  -69.3632      0.90        83          98
# 2   Butaritari      KI   3.0707  172.7902     80.11        75         100
# 3  Chake Chake      TZ  -5.2459   39.7666     81.82        76          15
# 4       Hobart      AU -42.8794  147.3294     57.22       100          75
#
#    Wind Speed Current Description
# 0        7.99          few clouds
# 1        3.83     overcast clouds
# 2       12.06     overcast clouds
# 3        9.95          few clouds
# 4        4.61       broken clouds
