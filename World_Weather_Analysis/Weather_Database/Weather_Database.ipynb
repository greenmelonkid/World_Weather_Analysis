# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 744

# %%
import requests

from config import weather_api_key

import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
#city_data = []

# Print the beginning of the logging.
#print("Beginning Data Retrieval    ")
#print("----------------------------")

# Create counters.
#record_count = 1
#set_count = 1

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
       

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
   
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_des = city_weather["weather"][0]["description"]
          
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_des})    
     


    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | taltal
# Processing Record 5 of Set 1 | henties bay
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | roald
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | kutum
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 1 | cherskiy
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | pisco
# Processing Record 21 of Set 1 | calama
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 1 | qeshm
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | mehamn
# Processing Record 32 of Set 1 | longyearbyen
# Processing Record 33 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | half moon bay
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | sistranda
# Processing Record 38 of Set 1 | dingle
# Processing Record 39 of Set 1 | dashitou
# Processing Record 40 of Set 1 | esperance
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | norrtalje
# Processing Record 43 of Set 1 | bandarbeyla
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | high level
# Processing Record 46 of Set 1 | totma
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | dunedin
# Processing Record 50 of Set 1 | rorvik
# Processing Record 1 of Set 2 | komsomolskiy
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | nuuk
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | laguna
# Processing Record 15 of Set 2 | leh
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | saint-louis
# Processing Record 18 of Set 2 | hovd
# Processing Record 19 of Set 2 | codrington
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | punta umbria
# Processing Record 23 of Set 2 | sechura
# Processing Record 24 of Set 2 | riyadh
# Processing Record 25 of Set 2 | flinders
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | bafq
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | yar-sale
# Processing Record 30 of Set 2 | kaeo
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | bowen
# Processing Record 33 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 2 | kupang
# Processing Record 35 of Set 2 | rafraf
# Processing Record 36 of Set 2 | inirida
# Processing Record 37 of Set 2 | baijiantan
# Processing Record 38 of Set 2 | shahkot
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | tucumcari
# Processing Record 41 of Set 2 | klaksvik
# Processing Record 42 of Set 2 | praia
# Processing Record 43 of Set 2 | morbegno
# Processing Record 44 of Set 2 | oistins
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | fukue
# Processing Record 47 of Set 2 | santa vitoria
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | salinopolis
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | samfya
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | port moresby
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | havelock
# Processing Record 12 of Set 3 | timaru
# Processing Record 13 of Set 3 | ajdabiya
# Processing Record 14 of Set 3 | arlit
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | cayenne
# Processing Record 17 of Set 3 | alta floresta
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | bontang
# Processing Record 20 of Set 3 | nsanje
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | tuatapere
# Processing Record 23 of Set 3 | alofi
# Processing Record 24 of Set 3 | manzhouli
# Processing Record 25 of Set 3 | orangeburg
# Processing Record 26 of Set 3 | tagusao
# Processing Record 27 of Set 3 | ballina
# Processing Record 28 of Set 3 | khani
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | tatarsk
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | jutai
# Processing Record 33 of Set 3 | enid
# Processing Record 34 of Set 3 | itacare
# Processing Record 35 of Set 3 | kenai
# Processing Record 36 of Set 3 | oriximina
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | sturgeon falls
# Processing Record 39 of Set 3 | alvaraes
# Processing Record 40 of Set 3 | bathsheba
# Processing Record 41 of Set 3 | biltine
# Processing Record 42 of Set 3 | fortuna
# Processing Record 43 of Set 3 | bluff
# Processing Record 44 of Set 3 | sao filipe
# Processing Record 45 of Set 3 | emerald
# Processing Record 46 of Set 3 | mnogovershinnyy
# Processing Record 47 of Set 3 | comarapa
# Processing Record 48 of Set 3 | salalah
# Processing Record 49 of Set 3 | sangar
# Processing Record 50 of Set 3 | namatanai
# Processing Record 1 of Set 4 | moranbah
# Processing Record 2 of Set 4 | itarema
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | umm kaddadah
# Processing Record 5 of Set 4 | krasnoselkup
# Processing Record 6 of Set 4 | iraquara
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | brae
# Processing Record 9 of Set 4 | saldanha
# Processing Record 10 of Set 4 | valle de allende
# Processing Record 11 of Set 4 | santiago de cao
# Processing Record 12 of Set 4 | ayan
# Processing Record 13 of Set 4 | kirovskiy
# Processing Record 14 of Set 4 | suao
# City not found. Skipping...
# Processing Record 15 of Set 4 | amahai
# Processing Record 16 of Set 4 | hondo
# Processing Record 17 of Set 4 | madera
# Processing Record 18 of Set 4 | batemans bay
# Processing Record 19 of Set 4 | umm lajj
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | aden
# Processing Record 22 of Set 4 | klerksdorp
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | broken hill
# Processing Record 25 of Set 4 | qaanaaq
# Processing Record 26 of Set 4 | yerbogachen
# Processing Record 27 of Set 4 | fuzhou
# Processing Record 28 of Set 4 | coihaique
# Processing Record 29 of Set 4 | hofn
# Processing Record 30 of Set 4 | kayes
# Processing Record 31 of Set 4 | snezhnogorsk
# Processing Record 32 of Set 4 | saint-jean-de-maurienne
# Processing Record 33 of Set 4 | ostrovnoy
# Processing Record 34 of Set 4 | aklavik
# Processing Record 35 of Set 4 | neiafu
# Processing Record 36 of Set 4 | hami
# Processing Record 37 of Set 4 | izyum
# Processing Record 38 of Set 4 | santa rosa
# Processing Record 39 of Set 4 | guerrero negro
# Processing Record 40 of Set 4 | wladyslawowo
# Processing Record 41 of Set 4 | alugan
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | saskylakh
# Processing Record 44 of Set 4 | okandja
# City not found. Skipping...
# Processing Record 45 of Set 4 | bitung
# Processing Record 46 of Set 4 | college
# Processing Record 47 of Set 4 | eureka
# Processing Record 48 of Set 4 | alice springs
# Processing Record 49 of Set 4 | kodiak
# Processing Record 50 of Set 4 | pahrump
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | matagami
# Processing Record 3 of Set 5 | margate
# Processing Record 4 of Set 5 | kuleshovka
# Processing Record 5 of Set 5 | aksarka
# Processing Record 6 of Set 5 | beringovskiy
# Processing Record 7 of Set 5 | sabang
# Processing Record 8 of Set 5 | lady frere
# Processing Record 9 of Set 5 | mormugao
# Processing Record 10 of Set 5 | vila
# Processing Record 11 of Set 5 | coquimbo
# Processing Record 12 of Set 5 | sinnamary
# Processing Record 13 of Set 5 | roma
# Processing Record 14 of Set 5 | yendi
# Processing Record 15 of Set 5 | votkinsk
# Processing Record 16 of Set 5 | gannan
# Processing Record 17 of Set 5 | pangody
# Processing Record 18 of Set 5 | chuy
# Processing Record 19 of Set 5 | bardiyah
# Processing Record 20 of Set 5 | chegutu
# Processing Record 21 of Set 5 | santa catalina
# Processing Record 22 of Set 5 | logan
# Processing Record 23 of Set 5 | okha
# Processing Record 24 of Set 5 | esna
# Processing Record 25 of Set 5 | bubaque
# Processing Record 26 of Set 5 | tombouctou
# Processing Record 27 of Set 5 | kopayhorod
# Processing Record 28 of Set 5 | redlands
# Processing Record 29 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 5 | storforshei
# Processing Record 33 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 5 | olafsvik
# Processing Record 35 of Set 5 | buchanan
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | russell
# Processing Record 38 of Set 5 | erzin
# Processing Record 39 of Set 5 | gogrial
# Processing Record 40 of Set 5 | hambantota
# Processing Record 41 of Set 5 | rurrenabaque
# Processing Record 42 of Set 5 | maumere
# Processing Record 43 of Set 5 | miandrivazo
# Processing Record 44 of Set 5 | diamantino
# Processing Record 45 of Set 5 | cadiz
# Processing Record 46 of Set 5 | kushmurun
# Processing Record 47 of Set 5 | clarence town
# Processing Record 48 of Set 5 | ravar
# Processing Record 49 of Set 5 | vendas novas
# Processing Record 50 of Set 5 | ahipara
# Processing Record 1 of Set 6 | trabzon
# Processing Record 2 of Set 6 | areka
# Processing Record 3 of Set 6 | vilyuysk
# Processing Record 4 of Set 6 | grand-lahou
# Processing Record 5 of Set 6 | odweyne
# Processing Record 6 of Set 6 | shasta lake
# Processing Record 7 of Set 6 | phuket
# Processing Record 8 of Set 6 | jaicos
# Processing Record 9 of Set 6 | belmonte
# Processing Record 10 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 6 | ducheng
# Processing Record 12 of Set 6 | kibala
# Processing Record 13 of Set 6 | katima mulilo
# Processing Record 14 of Set 6 | ilulissat
# Processing Record 15 of Set 6 | gambela
# Processing Record 16 of Set 6 | celestun
# Processing Record 17 of Set 6 | vung tau
# Processing Record 18 of Set 6 | pangnirtung
# Processing Record 19 of Set 6 | mount gambier
# Processing Record 20 of Set 6 | leningradskiy
# Processing Record 21 of Set 6 | rivera
# Processing Record 22 of Set 6 | atherton
# Processing Record 23 of Set 6 | bloemfontein
# Processing Record 24 of Set 6 | myitkyina
# Processing Record 25 of Set 6 | zheleznodorozhnyy
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | kiruna
# Processing Record 28 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 6 | charlestown
# Processing Record 30 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 6 | emba
# Processing Record 32 of Set 6 | la palma
# Processing Record 33 of Set 6 | auki
# Processing Record 34 of Set 6 | sola
# Processing Record 35 of Set 6 | koungou
# Processing Record 36 of Set 6 | piacabucu
# Processing Record 37 of Set 6 | loa janan
# Processing Record 38 of Set 6 | yantal
# Processing Record 39 of Set 6 | bereda
# Processing Record 40 of Set 6 | lavrentiya
# Processing Record 41 of Set 6 | husavik
# Processing Record 42 of Set 6 | buala
# Processing Record 43 of Set 6 | kalmunai
# Processing Record 44 of Set 6 | harbour breton
# Processing Record 45 of Set 6 | san patricio
# Processing Record 46 of Set 6 | maputo
# Processing Record 47 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 6 | soyo
# Processing Record 49 of Set 6 | cap malheureux
# Processing Record 50 of Set 6 | richards bay
# Processing Record 1 of Set 7 | korla
# Processing Record 2 of Set 7 | sainte-marie
# Processing Record 3 of Set 7 | kushima
# Processing Record 4 of Set 7 | filadelfia
# Processing Record 5 of Set 7 | kuching
# Processing Record 6 of Set 7 | vanimo
# Processing Record 7 of Set 7 | poykovskiy
# Processing Record 8 of Set 7 | thompson
# Processing Record 9 of Set 7 | verkhnevilyuysk
# Processing Record 10 of Set 7 | baleshwar
# Processing Record 11 of Set 7 | walvis bay
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | smolenka
# Processing Record 14 of Set 7 | tuktoyaktuk
# Processing Record 15 of Set 7 | lahaina
# Processing Record 16 of Set 7 | purgstall
# Processing Record 17 of Set 7 | tomatlan
# Processing Record 18 of Set 7 | rapid city
# Processing Record 19 of Set 7 | vastervik
# City not found. Skipping...
# Processing Record 20 of Set 7 | kirsanov
# Processing Record 21 of Set 7 | golpayegan
# Processing Record 22 of Set 7 | hamilton
# Processing Record 23 of Set 7 | cabedelo
# Processing Record 24 of Set 7 | mitsamiouli
# Processing Record 25 of Set 7 | mount isa
# Processing Record 26 of Set 7 | veraval
# Processing Record 27 of Set 7 | estevan
# Processing Record 28 of Set 7 | isangel
# Processing Record 29 of Set 7 | griffith
# Processing Record 30 of Set 7 | bonthe
# Processing Record 31 of Set 7 | carnarvon
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | kita
# Processing Record 34 of Set 7 | caloundra
# Processing Record 35 of Set 7 | bochov
# Processing Record 36 of Set 7 | barda
# Processing Record 37 of Set 7 | perth
# Processing Record 38 of Set 7 | pemberton
# Processing Record 39 of Set 7 | zeya
# Processing Record 40 of Set 7 | shingu
# Processing Record 41 of Set 7 | port lincoln
# Processing Record 42 of Set 7 | fernley
# Processing Record 43 of Set 7 | altus
# Processing Record 44 of Set 7 | san carlos
# Processing Record 45 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 7 | cidreira
# Processing Record 47 of Set 7 | navahrudak
# Processing Record 48 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 49 of Set 7 | lorengau
# Processing Record 50 of Set 7 | nouadhibou
# Processing Record 1 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 8 | valparaiso
# Processing Record 3 of Set 8 | santa cruz de la palma
# Processing Record 4 of Set 8 | fulda
# Processing Record 5 of Set 8 | troitskoye
# Processing Record 6 of Set 8 | katangli
# Processing Record 7 of Set 8 | hongjiang
# Processing Record 8 of Set 8 | kayerkan
# Processing Record 9 of Set 8 | kapchorwa
# Processing Record 10 of Set 8 | nanortalik
# Processing Record 11 of Set 8 | abatskoye
# Processing Record 12 of Set 8 | bonavista
# Processing Record 13 of Set 8 | ndago
# Processing Record 14 of Set 8 | davidson
# Processing Record 15 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 16 of Set 8 | caravelas
# Processing Record 17 of Set 8 | port hardy
# Processing Record 18 of Set 8 | heinola
# Processing Record 19 of Set 8 | tiarei
# Processing Record 20 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 8 | leon
# Processing Record 22 of Set 8 | nome
# Processing Record 23 of Set 8 | jasper
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | tifton
# Processing Record 26 of Set 8 | pangoa
# Processing Record 27 of Set 8 | ponta do sol
# Processing Record 28 of Set 8 | burica
# City not found. Skipping...
# Processing Record 29 of Set 8 | samarai
# Processing Record 30 of Set 8 | karasjok
# Processing Record 31 of Set 8 | plastun
# Processing Record 32 of Set 8 | eatonton
# Processing Record 33 of Set 8 | lagoa
# Processing Record 34 of Set 8 | vao
# Processing Record 35 of Set 8 | kysyl-syr
# Processing Record 36 of Set 8 | lasa
# Processing Record 37 of Set 8 | romny
# Processing Record 38 of Set 8 | ouesso
# Processing Record 39 of Set 8 | gympie
# Processing Record 40 of Set 8 | smithers
# Processing Record 41 of Set 8 | tignere
# Processing Record 42 of Set 8 | bulacan
# Processing Record 43 of Set 8 | raymondville
# Processing Record 44 of Set 8 | ornskoldsvik
# Processing Record 45 of Set 8 | bintulu
# Processing Record 46 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 47 of Set 8 | verkhnetulomskiy
# Processing Record 48 of Set 8 | acapulco
# Processing Record 49 of Set 8 | fenyi
# Processing Record 50 of Set 8 | escanaba
# Processing Record 1 of Set 9 | conde
# Processing Record 2 of Set 9 | millinocket
# Processing Record 3 of Set 9 | ulladulla
# Processing Record 4 of Set 9 | kemijarvi
# Processing Record 5 of Set 9 | hvammstangi
# City not found. Skipping...
# Processing Record 6 of Set 9 | kieta
# Processing Record 7 of Set 9 | mandasa
# Processing Record 8 of Set 9 | kijang
# Processing Record 9 of Set 9 | ucluelet
# Processing Record 10 of Set 9 | baherden
# Processing Record 11 of Set 9 | rocha
# Processing Record 12 of Set 9 | hervey bay
# Processing Record 13 of Set 9 | iqaluit
# Processing Record 14 of Set 9 | nakhon phanom
# Processing Record 15 of Set 9 | joensuu
# Processing Record 16 of Set 9 | isla mujeres
# Processing Record 17 of Set 9 | xiaoweizhai
# Processing Record 18 of Set 9 | assare
# Processing Record 19 of Set 9 | polunochnoye
# Processing Record 20 of Set 9 | tucuman
# Processing Record 21 of Set 9 | kapoeta
# Processing Record 22 of Set 9 | west odessa
# Processing Record 23 of Set 9 | san cristobal
# Processing Record 24 of Set 9 | faanui
# Processing Record 25 of Set 9 | holme
# Processing Record 26 of Set 9 | maragogi
# Processing Record 27 of Set 9 | talcahuano
# Processing Record 28 of Set 9 | emmett
# Processing Record 29 of Set 9 | inuvik
# Processing Record 30 of Set 9 | hiji
# Processing Record 31 of Set 9 | berlevag
# Processing Record 32 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 9 | hit
# Processing Record 34 of Set 9 | sanchazi
# Processing Record 35 of Set 9 | axim
# Processing Record 36 of Set 9 | mantua
# Processing Record 37 of Set 9 | tual
# Processing Record 38 of Set 9 | puerto escondido
# Processing Record 39 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 9 | tres arroyos
# Processing Record 42 of Set 9 | pringsewu
# Processing Record 43 of Set 9 | necochea
# Processing Record 44 of Set 9 | mbandaka
# Processing Record 45 of Set 9 | solwezi
# Processing Record 46 of Set 9 | ambilobe
# Processing Record 47 of Set 9 | iskateley
# Processing Record 48 of Set 9 | altamira
# Processing Record 49 of Set 9 | vestmanna
# Processing Record 50 of Set 9 | makakilo city
# Processing Record 1 of Set 10 | ouro preto do oeste
# Processing Record 2 of Set 10 | nianzishan
# Processing Record 3 of Set 10 | luderitz
# Processing Record 4 of Set 10 | rawson
# Processing Record 5 of Set 10 | goderich
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | chumikan
# Processing Record 8 of Set 10 | bilma
# Processing Record 9 of Set 10 | seoul
# Processing Record 10 of Set 10 | kenora
# Processing Record 11 of Set 10 | varna
# Processing Record 12 of Set 10 | tatarbunary
# Processing Record 13 of Set 10 | zamoly
# Processing Record 14 of Set 10 | loandjili
# Processing Record 15 of Set 10 | kiunga
# Processing Record 16 of Set 10 | ewa beach
# Processing Record 17 of Set 10 | xining
# Processing Record 18 of Set 10 | mindelo
# Processing Record 19 of Set 10 | cockburn town
# Processing Record 20 of Set 10 | chipinge
# Processing Record 21 of Set 10 | la cruz
# Processing Record 22 of Set 10 | nieuw nickerie
# Processing Record 23 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 10 | tenenkou
# Processing Record 25 of Set 10 | hualmay
# Processing Record 26 of Set 10 | tengzhou
# Processing Record 27 of Set 10 | sillamae
# Processing Record 28 of Set 10 | akdagmadeni
# Processing Record 29 of Set 10 | yeppoon
# Processing Record 30 of Set 10 | mahibadhoo
# Processing Record 31 of Set 10 | honiara
# Processing Record 32 of Set 10 | palotina
# Processing Record 33 of Set 10 | blythe
# Processing Record 34 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 10 | la libertad
# Processing Record 37 of Set 10 | grindavik
# Processing Record 38 of Set 10 | praia da vitoria
# Processing Record 39 of Set 10 | shablykino
# Processing Record 40 of Set 10 | saquena
# Processing Record 41 of Set 10 | diffa
# Processing Record 42 of Set 10 | sarkikaraagac
# Processing Record 43 of Set 10 | kargil
# Processing Record 44 of Set 10 | palmer
# Processing Record 45 of Set 10 | kavaratti
# Processing Record 46 of Set 10 | san rafael
# Processing Record 47 of Set 10 | manavalakurichi
# Processing Record 48 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 10 | geraldton
# Processing Record 50 of Set 10 | saint anthony
# Processing Record 1 of Set 11 | jacarezinho
# Processing Record 2 of Set 11 | pachino
# Processing Record 3 of Set 11 | vanavara
# Processing Record 4 of Set 11 | atar
# Processing Record 5 of Set 11 | la uribe
# City not found. Skipping...
# Processing Record 6 of Set 11 | nakhon nayok
# Processing Record 7 of Set 11 | anadyr
# Processing Record 8 of Set 11 | bilibino
# Processing Record 9 of Set 11 | tommot
# Processing Record 10 of Set 11 | tyumentsevo
# Processing Record 11 of Set 11 | kindu
# Processing Record 12 of Set 11 | ndele
# Processing Record 13 of Set 11 | kropotkin
# Processing Record 14 of Set 11 | kodinsk
# Processing Record 15 of Set 11 | kahului
# Processing Record 16 of Set 11 | pontianak
# Processing Record 17 of Set 11 | siavonga
# Processing Record 18 of Set 11 | egvekinot
# Processing Record 19 of Set 11 | dharchula
# Processing Record 20 of Set 11 | ambunti
# Processing Record 21 of Set 11 | athabasca
# Processing Record 22 of Set 11 | sokolka
# Processing Record 23 of Set 11 | new waterford
# Processing Record 24 of Set 11 | fairbanks
# Processing Record 25 of Set 11 | port augusta
# Processing Record 26 of Set 11 | liku

# %%
len(city_data)

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Eureka      US  40.8021 -124.1637     57.67        88          88
# 1      Mataura      NZ -46.1927  168.8643     62.20        73           8
# 2       Pavino      RU  59.1139   46.1414      3.96       100          90
# 3     San Juan      AR -31.5375  -68.5364     83.43        18           0
# 4  Pangnirtung      CA  66.1451  -65.7125     19.40        79         100
#
#    Wind Speed Current Description
# 0       10.00     overcast clouds
# 1        1.45           clear sky
# 2        3.74     overcast clouds
# 3       29.53           clear sky
# 4        3.44     overcast clouds

# %%
city_data_df.to_csv(r'C:\Users\lag86\OneDrive\Desktop\BOOTCAMP STUFF\Asynchronous---Challenge\Module 6 - APIs\World_Weather_Analysis- clone\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv')
